# %% [markdown]
# # E2MoCase

# %% [markdown]
# In this notebook we show how to obtain the raw data from which [E2MoCase](https://arxiv.org/pdf/2409.09001) was derived. Unfortunately, we cannot openly share the raw data due to [commercial restrictions](https://www.liri.uzh.ch/en/services/swissdox.html). Therefore, to get the complete dataset, including the raw data, please follow the steps described below.

# %% [markdown]
# As a first step, you’ll need to have a valid license for the [SwissDox API](https://liri.linguistik.uzh.ch/wiki/langtech/swissdox/api). Once you’ve obtained it, specify the X-API-Key and X-API-Secret headers in the [config/configuration.yaml](config/configuration.yaml) file.

# %% [markdown]
# Next, we need to run the queries located in the [Queries](./Queries) folder to retrieve the news data from SwissDox. The JSON files in this folder contain queries for each selected case in YAML format.

# %%
import os
import json
import glob
queries_path = './Queries'
yaml_queries = {}
pattern = os.path.join(queries_path, '*.json')
for filepath in glob.glob(pattern):
    with open(filepath, 'r', encoding='utf-8') as f:

        data = json.load(f)
        yaml_query = data.get('yaml_query')
        if yaml_query:
            yaml_queries[filepath] = yaml_query



print('Total number of queries:', len(yaml_queries))
print()
print('First query:', list(yaml_queries.values())[0])
# Out:
# Total number of queries: 52
#
# First query: query:
#   dates:
#     - from: 2019-01-01
#       to: 2024-03-31
#   content:
#     - Ahmaud Arbery
# result:
#   format: TSV
#   maxResults: 10000000
#   columns:
#     - id
#     - pubtime
#     - medium_code
#     - medium_name
#     - rubric
#     - regional
#     - doctype
#     - doctype_description
#     - language
#     - char_count
#     - dateline
#     - head
#     - subhead
#     - content_id
#     - content
# version: 1.2

# %% [markdown]
#  Now, we submit the query to SwissDox using the functions provided in the [**sw_lib.py**](utils/sw_lib.py) script:

# %%
from utils.sw_lib import submit_query, get_headers

header = get_headers(path='./config/configuration.yaml')
for name, query in yaml_queries.items():
    response, yaml_string = submit_query(query, name, name, header)

    if response['result'].lower() == 'ok':
        print('The response has been correctly submitted!')
print(response)

# %% [markdown]
# After submitting all the queries, you can check their status and download the query results either via the SwissDoc platform or by using the methods provided in the [utils/sw_lib.py](utils/sw_lib.py) class, as shown below.

# %%
from utils.sw_lib import check_status, check_status_id, get_query_id
from utils.util import download

save_dir = './artifacts'
header = get_headers()
status_all = check_status(header)

for query_name in yaml_queries.keys():
    query_id = get_query_id(status_all, query_name, case_sensitive=False)
    if query_id is None:
        print(f'Query not found for {query_name}!')
        continue

    file_name_ex = query_name + ".tsv.xz"

    json_id = check_status_id(query_id, header)[0]

    if json_id['status'] != 'finished':
        status = json_id['status']

        print(f'Status not finished for {query_name}!. Status is on {status}')
        continue
    if json_id['downloadUrl'] is None:
        status = json_id['status']
        results = json_id['actualResults']
        print(f'Status of {query_name} is {status} with {results} results')
        continue
    print(f'Downloading {query_name}')
    download(json_id['downloadUrl'], os.path.join(save_dir, file_name_ex), header) #download the file

# %% [markdown]
#  Once you’ve downloaded all the files, you’ll need to decompress them. This will produce a TSV file containing the following columns.
#
#             - id
#             - pubtime
#             - medium_code
#             - medium_name
#             - rubric
#             - regional
#             - doctype
#             - doctype_description
#             - language
#             - char_count
#             - dateline
#             - head
#             - subhead
#             - content_id
#             - content

# %% [markdown]
# The news content is located in the **content column**, which is enriched with markup tags such as <LG\> or <ParagTitle\>.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# To illustrate the preprocessing phase, let’s assume, for instance, that the query results are stored in the file [example_data.csv](./example_data.csv), which contains the columns **head, subhead, content_id, and content**. Below, we describe the code used to clean the content by removing markup tags, translating the text into English, and splitting it into paragraph

# %%
import pandas as pd
df = pd.read_csv('example_data.csv', sep='\t')
#Note that the data shown in this example are not real news data extracted from SwissDox, but they were synthetically generated for illustrative purposes.
print(df.head(2))
# Out:
#                              content_id language  \
# 0  01a7d373-b97a-336c-f318-43518eff51c8       en
# 1  02b7d373-c97b-446c-f318-43518eff51c9       en
#
#                                    head  \
# 0            Nova Kakhovka Dam Collapse
# 1  Historic Vote Ousts US House Speaker
#
#                                    subhead  \
# 0  Widespread Flooding in Southern Ukraine
# 1  Kevin McCarthy Removed by Narrow Margin
#
#                                              content
# 0  In early June 2023, the Nova Kakhovka dam in s...
# 1  In a dramatic turn of events on Capitol Hill, ...

# %%
df['medium_code'] = 'TEXT' # assume everything is text

# %%
from deep_translator import GoogleTranslator
from utils import sw_handler as text_handler
from tqdm import tqdm



for index, row in tqdm(df.iterrows(), total=len(df), desc=f"Pre-processing data",):
    #We avoid content coming from audio or video transcription 
    if text_handler.is_audio_video_text(row): 
        print("No text: audio or video transcription")
        continue
    
    cleaned_content = text_handler.get_content_in_paragraphs(row) # clean data
    cleaned_content = "\n".join(cleaned_content) # reconstruct the content as a string
    row['cleaned_content'] = cleaned_content
    
    if cleaned_content=="": continue
    if len(cleaned_content)<=1: continue
    
    
    language= row["language"]
    if language != 'en':
        head = GoogleTranslator(source=language, target='en').translate(row["head"]) 
        df.loc[index,"translated_head"]=head
        subhead= "" if type(row["subhead"])!=str else GoogleTranslator(source=language, target='en').translate(row["subhead"]) 
        df.loc[index,"translated_subhead"]=subhead
        
        text = GoogleTranslator(source=language, target='en').translate(cleaned_content)
        if not isinstance(text, str): 
            text=''
        if text == '': continue
        translated_input=text

        df.loc[index,"translated_input"]= text
    else:
        df.loc[index,"translated_head"]=row['head']
        df.loc[index,"translated_subhead"]=row['subhead']
        df.loc[index,"translated_input"]= cleaned_content
# Out:
# Pre-processing data: 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]

# %%
df.tail(5)
# Out:
#                              content_id language  \
# 5  227d4d3d-8148-4ed6-8ec0-4455ebc2437e       fr
# 6  ecc63b07-9653-4ac5-923d-f609575719e8       fr
# 7  2a79d0fe-29a3-4cd5-9ac2-2538f47eaf0f       de
# 8  ad700303-5da1-4226-bf4b-5e83b85154c3       de
# 9  f45e5a0c-e365-4097-b5ef-572ebc1ed304       it
#
#                                   head  \
# 5      Réforme des Retraites en France
# 6          Séisme Dévastateur au Maroc
# 7  Technische Rezession in Deutschland
# 8    Ende der Atomkraft in Deutschland
# 9           Arresto Storico in Sicilia
#
#                                            subhead  \
# 5        Grèves Massives et Contestations Sociales
# 6           Aide Internationale et Reconstructions
# 7           BIP Zwei Quartale in Folge Geschrumpft
# 8               Letzte Drei AKWs vom Netz Genommen
# 9  Matteo Messina Denaro Catturato Dopo Trent’Anni
#
#                                              content medium_code  \
# 5  La France a connu une période particulièrement...        TEXT
# 6  Le Maroc a été frappé en septembre 2023 par un...        TEXT
# 7  Deutschland rutschte Ende 2022 und Anfang 2023...        TEXT
# 8  Im April 2023 wurden in Deutschland die letzte...        TEXT
# 9  Nel gennaio 2023, le forze dell’ordine italian...        TEXT
#
#                      translated_head  \
# 5           Pension reform in France
# 6  Devastating earthquake in Morocco
# 7     Technical recession in Germany
# 8    End of nuclear power in Germany
# 9        Historical arrest in Sicily
#
#                                   translated_subhead  \
# 5                Massive strikes and social disputes
# 6              International aid and reconstructions
# 7                   GDP Two quarters in a row shrunk
# 8  Last three nuclear power plant removed from th...
# 9   Matteo Messina money captured after thirty years
#
#                                     translated_input
# 5  Pension reform in France\nMassive strikes and ...
# 6  Devastating earthquake in Morocco\nInternation...
# 7  Technical recession in Germany\nGDP Two quarte...
# 8  End of nuclear power in Germany\nLast three nu...
# 9  Historical arrest in Sicily\nMatteo Messina mo...

# %% [markdown]
# After the text has been cleaned and translated, we split it into paragraphs, as shown below.

# %%
res_list = []
for index, row in df.iterrows():
    language= row["language"]
    paragraphs= text_handler.get_content_in_paragraphs(row)
    if paragraphs=="":continue
    for parag_id, p in enumerate(paragraphs):
      res_list.append({"content_id":row["content_id"], "P": "P"+str(parag_id),"language":language, "translated_input": p})

dfs = [pd.DataFrame(row, index=[0]) for row in res_list]
res_df = pd.concat(dfs, ignore_index=True)

# %%
res_df
# Out:
#                               content_id   P language  \
# 0   01a7d373-b97a-336c-f318-43518eff51c8  P0       en
# 1   01a7d373-b97a-336c-f318-43518eff51c8  P1       en
# 2   01a7d373-b97a-336c-f318-43518eff51c8  P2       en
# 3   01a7d373-b97a-336c-f318-43518eff51c8  P3       en
# 4   02b7d373-c97b-446c-f318-43518eff51c9  P0       en
# 5   02b7d373-c97b-446c-f318-43518eff51c9  P1       en
# 6   02b7d373-c97b-446c-f318-43518eff51c9  P2       en
# 7   02b7d373-c97b-446c-f318-43518eff51c9  P3       en
# 8   03c7d373-d97c-556c-f318-43518eff51ca  P0       en
# 9   03c7d373-d97c-556c-f318-43518eff51ca  P1       en
# 10  03c7d373-d97c-556c-f318-43518eff51ca  P2       en
# 11  03c7d373-d97c-556c-f318-43518eff51ca  P3       en
# 12  82b2d2fa-2284-4f66-af3b-1859825b7836  P0       en
# 13  82b2d2fa-2284-4f66-af3b-1859825b7836  P1       en
# 14  82b2d2fa-2284-4f66-af3b-1859825b7836  P2       en
# 15  82b2d2fa-2284-4f66-af3b-1859825b7836  P3       en
# 16  6187fc2b-1f24-4b86-beb6-838534c91021  P0       en
# 17  6187fc2b-1f24-4b86-beb6-838534c91021  P1       en
# 18  6187fc2b-1f24-4b86-beb6-838534c91021  P2       en
# 19  6187fc2b-1f24-4b86-beb6-838534c91021  P3       en
# 20  227d4d3d-8148-4ed6-8ec0-4455ebc2437e  P0       fr
# 21  227d4d3d-8148-4ed6-8ec0-4455ebc2437e  P1       fr
# 22  227d4d3d-8148-4ed6-8ec0-4455ebc2437e  P2       fr
# 23  227d4d3d-8148-4ed6-8ec0-4455ebc2437e  P3       fr
# 24  ecc63b07-9653-4ac5-923d-f609575719e8  P0       fr
# 25  ecc63b07-9653-4ac5-923d-f609575719e8  P1       fr
# 26  ecc63b07-9653-4ac5-923d-f609575719e8  P2       fr
# 27  ecc63b07-9653-4ac5-923d-f609575719e8  P3       fr
# 28  2a79d0fe-29a3-4cd5-9ac2-2538f47eaf0f  P0       de
# 29  2a79d0fe-29a3-4cd5-9ac2-2538f47eaf0f  P1       de
# 30  2a79d0fe-29a3-4cd5-9ac2-2538f47eaf0f  P2       de
# 31  2a79d0fe-29a3-4cd5-9ac2-2538f47eaf0f  P3       de
# 32  ad700303-5da1-4226-bf4b-5e83b85154c3  P0       de
# 33  ad700303-5da1-4226-bf4b-5e83b85154c3  P1       de
# 34  ad700303-5da1-4226-bf4b-5e83b85154c3  P2       de
# 35  ad700303-5da1-4226-bf4b-5e83b85154c3  P3       de
# 36  f45e5a0c-e365-4097-b5ef-572ebc1ed304  P0       it
# 37  f45e5a0c-e365-4097-b5ef-572ebc1ed304  P1       it
# 38  f45e5a0c-e365-4097-b5ef-572ebc1ed304  P2       it
# 39  f45e5a0c-e365-4097-b5ef-572ebc1ed304  P3       it
#
#                                      translated_input
# 0   Nova Kakhovka Dam Collapse\nWidespread Floodin...
# 1   In early June 2023, the Nova Kakhovka dam in s...
# 2   International observers immediately raised con...
# 3   Both Ukrainian and Russian authorities exchang...
# 4   Historic Vote Ousts US House Speaker\nKevin Mc...
# 5   In a dramatic turn of events on Capitol Hill, ...
# 6   The unprecedented vote plunged Congress into t...
# 7   Following the vote, McCarthy briefly addressed...
# 8   India’s Chandrayaan-3 Lunar Triumph\nHistoric ...
# 9   In late August 2023, India achieved a signific...
# 10  Engineers at the Indian Space Research Organis...
# 11  Beyond national pride, the successful landing ...
# 12  WHO Ends COVID-19 Emergency\nGlobal Focus Shif...
# 13  In mid-2023, the World Health Organization off...
# 14  Across the globe, healthcare systems began shi...
# 15  Economists and public health experts also warn...
# 16  Record-Breaking Global Heatwaves\nJuly 2023 Cr...
# 17  Climate scientists have confirmed that July 20...
# 18  Public health agencies worldwide reported spik...
# 19  Environmental advocates argue that these simul...
# 20  Réforme des Retraites en France\nGrèves Massiv...
# 21  La France a connu une période particulièrement...
# 22  Malgré l’opposition d’une grande partie de la ...
# 23  À la suite de la promulgation de la réforme, c...
# 24  Séisme Dévastateur au Maroc\nAide Internationa...
# 25  Le Maroc a été frappé en septembre 2023 par un...
# 26  Le gouvernement marocain a rapidement sollicit...
# 27  Les experts estiment que la reconstruction pre...
# 28  Technische Rezession in Deutschland\nBIP Zwei ...
# 29  Deutschland rutschte Ende 2022 und Anfang 2023...
# 30  Die Bundesregierung kündigte daraufhin ein umf...
# 31  Die Diskussion über mögliche Wege aus der Reze...
# 32  Ende der Atomkraft in Deutschland\nLetzte Drei...
# 33  Im April 2023 wurden in Deutschland die letzte...
# 34  Kritiker weisen allerdings darauf hin, dass De...
# 35  Die Regierung plant, verstärkt in den Ausbau v...
# 36  Arresto Storico in Sicilia\nMatteo Messina Den...
# 37  Nel gennaio 2023, le forze dell’ordine italian...
# 38  Secondo le autorità, l’arresto ha richiesto an...
# 39  Il governo e la magistratura sperano che dalla...

# %% [markdown]
# The **(content_id, P) pair** uniquely identifies a row. Therefore, to reconstruct the original dataset, simply merge the dataframe df with the derivated data contained in the file [e2mocase.csv](e2mocase.csv) using this pair as the key.

# %%
df_derived = pd.read_csv('e2mocase.csv', sep='\t')

e2mocase = pd.merge(df_derived, df, on=['content_id', 'P'], how='inner')
